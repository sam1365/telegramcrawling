# %%
# %load_ext dotenv
# %dotenv
import requests

# %%
import os
token = os.environ["TOKEN"]
id =  os.environ["ID"]
base_url = f'https://api.telegram.org/bot{token}/sendMessage?chat_id={id}&text=ok'
requests.get(base_url)
